# %%
import geopandas as gpd, pandas as pd
# %matplotlib inline

# %%
#load stat area (https://data.gov.il/dataset/statistical-area-2008), dissolve by town
gdf_stats = gpd.read_file('data/stat_area/stat_2008_NEW_04Nov_1335.shp', encoding='windows-1255')
gdf_stats2 = gdf_stats.dissolve(by='SEMEL_YISH').reset_index()
#load town names
df_yishuv = pd.read_excel('data/bycode2018.xlsx', encoding='windows-1255')
##load stat area
df_stat_areas = pd.read_excel('data/cbs/מפתח-רחובותיים.xls', sheet_name=1, encoding='windows-1255')

# %%
gdf_stats.loc[gdf_stats['SEMEL_YISH']<10000]
# Out:
#       OBJECTID  SEMEL_YISH  STAT08  YISHUV_STA         Shem_Yishu  \
# 0            1          -2       0           0      שטח ללא שיפוט
# 1            2           7       1       70001                שחר
# 2            3          10       1      100001              תירוש
# 3            4          11       1      110001             ניר חן
# 4            5          13       1      130001               חצבה
# ...        ...         ...     ...         ...                ...
# 3026      3027        9700      34    97000034          הוד השרון
# 3027      3028        9800       1    98000001  בנימינה-גבעת עדה*
# 3028      3029        9800       2    98000002  בנימינה-גבעת עדה*
# 3029      3030        9800       3    98000003  בנימינה-גבעת עדה*
# 3030      3031        9800       4    98000004  בנימינה-גבעת עדה*
#
#                 Shem_Yis_1     Shape_Leng    Shape_Area  \
# 0                     None  724681.884774  4.622823e+08
# 1                   SHAHAR   11591.466653  6.802526e+06
# 2                   TIROSH    2981.465220  4.445150e+05
# 3                  NIR HEN   11808.357935  5.983378e+06
# 4                   HAZEVA   17954.580825  1.780427e+07
# ...                    ...            ...           ...
# 3026          HOD HASHARON    4441.780985  7.331411e+05
# 3027  BINYAMINA-GIV'AT ADA   20380.152259  1.201555e+07
# 3028  BINYAMINA-GIV'AT ADA   14312.161323  5.376153e+06
# 3029  BINYAMINA-GIV'AT ADA    7126.685038  1.971719e+06
# 3030  BINYAMINA-GIV'AT ADA   12077.944511  6.114705e+06
#
#                                                geometry
# 0     MULTIPOLYGON (((200744.067 559233.546, 200635....
# 1     POLYGON ((175321.796 614938.868, 175333.156 61...
# 2     POLYGON ((189452.960 628792.606, 189478.444 62...
# 3     POLYGON ((174217.991 612806.233, 174229.531 61...
# 4     POLYGON ((227308.884 517640.396, 227283.976 51...
# ...                                                 ...
# 3026  POLYGON ((190697.020 671104.439, 190700.480 67...
# 3027  POLYGON ((200839.511 715667.430, 200901.511 71...
# 3028  POLYGON ((196240.863 717579.139, 196241.190 71...
# 3029  POLYGON ((194269.540 715258.152, 194284.597 71...
# 3030  POLYGON ((195435.200 713909.499, 195440.970 71...
#
# [3031 rows x 9 columns]

# %%
##clean df_stats_areas
df = df_stat_areas 
#rename columns
df.rename(columns={df.columns[0]:'town',
                   df.columns[1]:'town_code',
                   df.columns[2]:'stat_code',
                   df.columns[3]:'main_neighbourhoods',
                   df.columns[4]:'main_street'},inplace=True)
#set main street as first neighbourhoods if nan
df['main_street'] = [y.split(', ')[0] if x!=x else x for x, y in zip(df['main_street'], df['main_neighbourhoods'])]
df_stat_areas = df
# df_stat_areas.head()
# Out:
#          town  town_code  stat_code  \
# 0    אבו סנאן        473          1
# 1    אבו סנאן        473          2
# 2    אבו סנאן        473          3
# 3  אום אל-פחם       2710         11
# 4  אום אל-פחם       2710         12
#
#                                  main_neighbourhoods  main_street
# 0  אזור תעשייה, אלח'רוב, אלחלקאת, אלמלה, אלעקבה, ...  אזור תעשייה
# 1  אלג'ורה, אלמפצלה, אלשוקפאן, הואדי, כרם אלרג'ומ...      אלג'ורה
# 2             אבו-אלחסן, אלהדאפה, אלע'וזה, שכ' המסגד    אבו-אלחסן
# 3                                        עין אבראהים  עין אבראהים
# 4                                  אלבאטן, אלג'זאלאת       אלבאטן

# %%
gdf_stats.head()
gdf_stats.columns
# Out:
# Index(['OBJECTID', 'SEMEL_YISH', 'STAT08', 'YISHUV_STA', 'Shem_Yishu',
#        'Shem_Yis_1', 'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
gdf_stats.loc[gdf_stats['Shem_Yishu'].str.contains("טירה") ]
# Out:
#      OBJECTID  SEMEL_YISH  STAT08  YISHUV_STA Shem_Yishu Shem_Yis_1  \
# 629       630        2720       1    27200001       טירה       TIRE
# 630       631        2720       2    27200002       טירה       TIRE
# 631       632        2720       3    27200003       טירה       TIRE
# 632       633        2720       4    27200004       טירה       TIRE
# 633       634        2720       5    27200005       טירה       TIRE
# 634       635        2720       6    27200006       טירה       TIRE
# 635       636        2720       7    27200007       טירה       TIRE
# 636       637        2720       8    27200008       טירה       TIRE
#
#        Shape_Leng    Shape_Area  \
# 629  10066.268852  3.012049e+06
# 630   9785.406832  4.266692e+06
# 631   7236.412866  1.896463e+06
# 632   3847.320582  5.145911e+05
# 633   3691.754019  3.917902e+05
# 634   3661.085908  6.988156e+05
# 635   3137.298355  5.000175e+05
# 636   3786.479370  6.214717e+05
#
#                                               geometry
# 629  POLYGON ((196301.740 684401.220, 196356.142 68...
# 630  POLYGON ((197563.530 683190.130, 197567.770 68...
# 631  POLYGON ((196416.431 681832.250, 196462.012 68...
# 632  POLYGON ((195429.619 682497.605, 195442.930 68...
# 633  POLYGON ((195142.229 681932.080, 195161.400 68...
# 634  POLYGON ((194746.501 682615.060, 194764.810 68...
# 635  POLYGON ((195352.200 683405.620, 195332.650 68...
# 636  POLYGON ((195782.550 682547.690, 195776.691 68...

# %%
gdf_stats.loc[gdf_stats['Shem_Yishu'].isin(list(missing_towns['town']))]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in to_html(self, buf, encoding, classes, notebook, border)
#     981         Klass = NotebookFormatter if notebook else HTMLFormatter
#     982         return Klass(self, classes=classes, border=border).get_result(
# --> 983             buf=buf, encoding=encoding
#     984         )
#     985
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in get_result(self, buf, encoding)
#     519         """
#     520         with self.get_buffer(buf, encoding=encoding) as f:
# --> 521             self.write_result(buf=f)
#     522             if buf is None:
#     523                 return f.getvalue()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     952             na_rep=self.na_rep,
#     953             space=self.col_space,
# --> 954             decimal=self.decimal,
#     955         )
#     956
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1170     )
#    1171
# -> 1172     return fmt_obj.get_result()
#    1173
#    1174
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in get_result(self)
#    1201
#    1202     def get_result(self) -> List[str]:
# -> 1203         fmt_values = self._format_strings()
#    1204         return _make_fixed_width(fmt_values, self.justify)
#    1205
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1481             values = values._values
#    1482
# -> 1483         formatter = values._formatter(boxed=True)
#    1484
#    1485         if is_categorical_dtype(values.dtype):
#
# ~\Anaconda3\lib\site-packages\geopandas\array.py in _formatter(self, boxed)
#    1009                 # dummy heuristic based on 10 first geometries that should
#    1010                 # work in most cases
# -> 1011                 xmin, ymin, xmax, ymax = self[~self.isna()][:10].total_bounds
#    1012                 if (
#    1013                     (-180 <= xmin <= 180)
#
# ~\Anaconda3\lib\site-packages\geopandas\array.py in total_bounds(self)
#     750         return np.array(
#     751             (
# --> 752                 b[:, 0].min(),  # minx
#     753                 b[:, 1].min(),  # miny
#     754                 b[:, 2].max(),  # maxx
#
# IndexError: too many indices for array
# Empty GeoDataFrame
# Columns: [OBJECTID, SEMEL_YISH, STAT08, YISHUV_STA, Shem_Yishu, Shem_Yis_1, Shape_Leng, Shape_Area, geometry]
# Index: []

# %%
#merge dis_stats area
merged = gdf_stats.merge(df_yishuv, left_on='SEMEL_YISH', right_on='סמל יישוב', how='inner')
#remove columns and rename
merged_clean = merged[['SEMEL_YISH', 'Shem_Yishu', 'Shem_Yis_1', 'geometry']]
merged_clean = merged_clean.rename(columns={'SEMEL_YISH':'town_code',
                                            'Shem_Yishu':'town_name',
                                            'Shem_Yis_1':'town_name_heb'})

# %%
# Out:
# 1195

# %%
#map of towns
merged_clean.plot(figsize=(10,20))

# %%
#load covid by area (https://data.gov.il/dataset/covid-19)
covid_area_df = pd.read_excel("data/geographic-summary-per-day-2020-06-07.xlsx", encoding='windows-1255')
#remove cases without town code
covid_area_df = covid_area_df.loc[covid_area_df['town_code']!=0].reset_index(drop=True)
covid_area_df.head()

# %%
len(covid_area_df)
# type(merged_clean)
# Out:
# 103682

# %%
#find missing towns (not in stats area)
test = merged_clean.merge(covid_area_df, on='town_code', how='outer')
missing_towns =test.loc[test.town_name_heb.isna(),['town_code','town']].drop_duplicates()

# %%
merged_clean.loc[merged_clean.town_name=='יהוד']
# Out:
#       town_code town_name town_name_heb  \
# 1190       9400      יהוד         YEHUD
#
#                                                geometry
# 1190  POLYGON ((190631.731 660096.910, 190631.750 66...

# %%
covid_area_df.loc[(covid_area_df.town_code==9400) & (covid_area_df.date=='2020-03-26')].head(10)
# Out:
#         town_code  agas_code       date accumulated_cases  new_cases_on_date  \
# 101245       9400        NaN 2020-03-26                15               True
# 101319       9400        1.0 2020-03-26               <15               True
# 101479       9400        4.0 2020-03-26                20               True
# 101559       9400        5.0 2020-03-26               <15               True
# 101633       9400        6.0 2020-03-26               <15               True
# 101710       9400        7.0 2020-03-26               <15               True
#
#        accumulated_recoveries  new_recoveries_on_date  \
# 101245                    <15                   False
# 101319                    <15                   False
# 101479                    <15                   False
# 101559                    <15                   False
# 101633                    <15                   False
# 101710                    <15                   False
#
#        accumulated_hospitalized  new_hospitalized_on_date accumulated_deaths  \
# 101245                      <15                     False                <15
# 101319                      <15                     False                <15
# 101479                      <15                     False                <15
# 101559                      <15                      True                <15
# 101633                      <15                     False                <15
# 101710                      <15                     False                <15
#
#         new_deaths_on_date  town
# 101245               False  יהוד
# 101319               False  יהוד
# 101479               False  יהוד
# 101559               False  יהוד
# 101633               False  יהוד
# 101710               False  יהוד

# %%
gdf_stats.loc[gdf_stats.SEMEL_YISH.isin(list(missing_towns['town_code']))]
# Out:
#      SEMEL_YISH                                           geometry  OBJECTID  \
# 931        1722  POLYGON ((226283.880 765122.850, 226288.450 76...      1539
#
#      STAT08  YISHUV_STA Shem_Yishu Shem_Yis_1   Shape_Leng    Shape_Area
# 931       1    17220001   מגדל תפן        NaN  7819.967714  2.811067e+06

# %%
#combine town and covid cases
combined_df = merged_clean.merge(covid_area_df, on='town_code',)
# Out:
# 103252

# %%
final_df = combined_df[['date','town_code','town_name','town_name_heb','accumulated_cases','geometry']].drop_duplicates()

# %%
date_list = combined_df['date'].unique()
for date in date_list:
    df = final_df.loc[final_df.date==date]
    print(df)
    break
# Out:
#              date  town_code     town_name   town_name_heb accumulated_cases  \
# 0      2020-03-26         28    מזכרת בתיה  MAZKERET BATYA               <15
# 83     2020-03-26         31        אופקים          OFAQIM               <15
# 687    2020-03-26         46         יבנאל        YAVNE'EL               <15
# 765    2020-03-26         47      כפר תבור     KEFAR TAVOR               <15
# 842    2020-03-26         53         עתלית           ATLIT               <15
# ...           ...        ...           ...             ...               ...
# 100889 2020-03-26       9400          יהוד           YEHUD               <15
# 101049 2020-03-26       9400          יהוד           YEHUD                20
# 101557 2020-03-26       9500  קריית ביאליק   QIRYAT BIALIK               <15
# 101881 2020-03-26       9600      קריית ים      QIRYAT YAM               <15
# 102339 2020-03-26       9700     הוד השרון    HOD HASHARON               <15
#
#                                                  geometry
# 0       POLYGON ((185026.281 640668.472, 185002.082 64...
# 83      POLYGON ((165691.740 579964.390, 165691.671 57...
# 687     POLYGON ((249234.850 738625.470, 249228.033 73...
# 765     POLYGON ((239161.580 735147.320, 239263.550 73...
# 842     POLYGON ((195632.010 738810.100, 195671.818 73...
# ...                                                   ...
# 100889  POLYGON ((190631.731 660096.910, 190631.750 66...
# 101049  POLYGON ((190631.731 660096.910, 190631.750 66...
# 101557  POLYGON ((208087.931 747491.010, 208087.210 74...
# 101881  POLYGON ((206599.790 749307.320, 206596.991 74...
# 102339  POLYGON ((190961.260 671328.351, 190969.547 67...
#
# [165 rows x 6 columns]

# %%
combined_df.to_file("covid_by_town.geojson", driver='GeoJSON', encoding='windows-1255')
